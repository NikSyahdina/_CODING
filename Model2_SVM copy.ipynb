# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(r"D:\uni dina\PSM2\_CODING\DATASET\preprocessed_data_v2.csv")

# %%
df
# Out:
#                                           tweet_content  label
# 0     lack understand small signific part caus anxie...      1
# 1     told parent depress hard get gen x peopl under...      1
# 2     depress someth dont speak even go also doubl e...      1
# 3     made tortilla fill pbj depress cure olivia dep...      1
# 4     gon na need depress med soon rainout spin equi...      1
# ...                                                 ...    ...
# 8128  go anyon charlott want come tonight play flash...      0
# 8129                                              sun x      0
# 8130                       where gvsu woman ya need one      0
# 8131  shoot tonight murder miskeeto mainli feet slig...      0
# 8132                      birdi lucki die morn sooo sad      0
#
# [8133 rows x 2 columns]

# %%
vectorizer = CountVectorizer()

# %%
# Fit the bag-of-words model to the 'tweet_content' column
bag = vectorizer.fit_transform(df['tweet_content'])

# Get unique words / tokens found in all the documents
unique_words = vectorizer.get_feature_names_out()  # use get_feature_names_out() instead of get_feature_names()

# Associate the indices with each unique word
vocabulary = vectorizer.vocabulary_

# Print the unique words / tokens
print("Unique words/tokens:")
print(unique_words)

# Print the vocabulary dictionary
print("\nVocabulary dictionary:")
print(vocabulary)

# Print the numerical feature vector
print("\nNumerical feature vector (bag-of-words):")
print(bag.toarray())
# Out:
# Unique words/tokens:
# ['aa' 'aaa' 'aaaaaaaand' ... 'zz' 'zzz' 'zzzz']
#
# Vocabulary dictionary:
# ...

# %%
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(bag, df['label'], test_size=0.3)

# Initialize NB classifier
nb = MultinomialNB()

# Train Naive Bayes classifier
nb.fit(X_train, y_train)

# Predict on test data
y_pred = nb.predict(X_test)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91      1236
#            1       0.87      0.98      0.92      1204
#
#     accuracy                           0.92      2440
#    macro avg       0.92      0.92      0.91      2440
# weighted avg       0.92      0.92      0.91      2440
#
# Accuracy: 91.52%

# %% [markdown]
# SAME PROBLEM.
